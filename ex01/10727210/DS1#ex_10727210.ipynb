# %%
order = 0
temp = ""
num = 0
count = 1
re = -1 
temp = input( "輸入數字介於1-9" )
order = int(temp)
temporder = order - 2

while num < 10**order :
    longcopy = str(num)
    long2 = len(longcopy)
    re = check( order, num )
    if  ( re == 0 or re == 3 and long2 >= order -1 ) :
          
        if ( re == 3 or num < 10**temporder ) :
            pass 
        elif ( num < 10** (order-1) )   :
            zeroNum = str(num)
            allTheNum = '0' + zeroNum
            print( "[", count,"]",allTheNum )
            count = count + 1
        else :
            print( "[", count, "]", num )
            count = count + 1
            
    num = num + 1
# Out:
# 輸入數字介於1-95
# [ 1 ] 01234
# [ 2 ] 01235
# [ 3 ] 01236
# [ 4 ] 01237
# [ 5 ] 01238
# [ 6 ] 01239
# [ 7 ] 01243
# [ 8 ] 01245
# [ 9 ] 01246
# [ 10 ] 01247
# [ 11 ] 01248
# [ 12 ] 01249
# [ 13 ] 01253
# [ 14 ] 01254
# [ 15 ] 01256
# [ 16 ] 01257
# [ 17 ] 01258
# [ 18 ] 01259
# [ 19 ] 01263
# [ 20 ] 01264
# [ 21 ] 01265
# [ 22 ] 01267
# [ 23 ] 01268
# [ 24 ] 01269
# [ 25 ] 01273
# [ 26 ] 01274
# [ 27 ] 01275
# [ 28 ] 01276
# [ 29 ] 01278
# [ 30 ] 01279
# [ 31 ] 01283
# [ 32 ] 01284
# [ 33 ] 01285
# [ 34 ] 01286
# [ 35 ] 01287
# [ 36 ] 01289
# [ 37 ] 01293
# [ 38 ] 01294
# [ 39 ] 01295
# [ 40 ] 01296
# [ 41 ] 01297
# [ 42 ] 01298
# [ 43 ] 01324
# [ 44 ] 01325
# [ 45 ] 01326
# [ 46 ] 01327
# [ 47 ] 01328
# [ 48 ] 01329
# [ 49 ] 01342
# [ 50 ] 01345
# [ 51 ] 01346
# [ 52 ] 01347
# [ 53 ] 01348
# [ 54 ] 01349
# [ 55 ] 01352
# [ 56 ] 01354
# [ 57 ] 01356
# [ 58 ] 01357
# [ 59 ] 01358
# [ 60 ] 01359
# [ 61 ] 01362
# [ 62 ] 01364
# [ 63 ] 01365
# [ 64 ] 01367
# [ 65 ] 01368
# [ 66 ] 01369
# ...

# %%
def check ( order, num ) :
    zero = 0
    one = 0
    two = 0
    three = 0
    four = 0
    five = 0
    six = 0
    seven = 0 
    eight = 0
    nine = 0
    
    
    wnum = str(num)
    long = len(wnum)
    
    
    count = 0 
    
    while count < long :
        if wnum[count] == '1' :
            one = one + 1
        if wnum[count] == '2' :
            two = two + 1
        if wnum[count] =='3' :
            three = three + 1
        if wnum[count] == '4' :
            four = four + 1
        if wnum[count] == '5' :
            five = five + 1
        if wnum[count] == '6' :
            six = six + 1
        if wnum[count] == '7' :
            seven = seven + 1
        if wnum[count] == '8' :
            eight = eight + 1     
        if wnum[count] =='9' :
            nine = nine + 1
        if wnum[count] =='0' :
            zero = zero + 1
        
        count = count + 1
        temporder = 0
        temporder = order - 1 
    
    if( zero > 0 and num < 10**temporder ) :
        return 3 
    
  
    if( one > 1 or two > 1 or three > 1 or four > 1 or five > 1 
       or six > 1 or seven > 1 or eight > 1 or nine > 1 or zero > 1 ) :
        return 1 
    else :
        return 0
